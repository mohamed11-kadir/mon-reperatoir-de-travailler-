# %%
import gzip
import os

path ='./data_base/'
var = os.listdir(path)

for x in var:
    path ='./data_base/'+x
    with gzip.open(path, 'rb') as f:
        file_content = f.read()
    all_cdr_in_file = file_content.decode('UTF-8')
    list_of_cdr = list(all_cdr_in_file.split("\n"))
    #print(list_of_cdr[0])
    for y in list_of_cdr:
        ligne = list(y.split(" "))
        #print(ligne)

# %%
import gzip
import os

path ='./data_base/'
var = os.listdir(path)

list_dict = []

for x in var:
    path ='./data_base/'+x
    with gzip.open(path, 'rb') as f:
        file_content = f.read()
    all_cdr_in_file = file_content.decode('UTF-8')
    list_of_cdr = list(all_cdr_in_file.split("\n"))


    for y in list_of_cdr:
        ligne = list(y.split(" "))
        #print(ligne)
        if ligne[0]!='':

            if ligne[5] in ['O']:

                if 'SUBSCRIBERCALL' in ligne:
                        
                        li_new=[]
                        for z in range(int(ligne[51])):
                            tab=z*6
                            nb=51+tab+1
                            li_new.append(ligne[nb])
                            nb=51+tab+2
                            li_new.append(ligne[nb])
                            nb=51+tab+3
                            li_new.append(ligne[nb])
                            nb=51+tab+4
                            li_new.append(ligne[nb])
                            nb=51+tab+5
                            li_new.append(ligne[nb])
                            nb=51+tab+6
                            li_new.append(ligne[nb])   

                        list_balance = []    
                        for z in range(int(len(li_new)/6)):
                            k=z*6
                            dis_balance={
                                "balance_name":li_new[k+0],
                                "billed_amount":li_new[k+1],
                                "balances_unit":li_new[k+2],
                                "balan_credit_before":li_new[k+3],
                                "after_call":li_new[k+4],
                                "balance_expiration_date":li_new[k+5],
                            }

                            list_balance.append(dis_balance)

                        
                        dis_labl= {
                                'id':ligne[0],
                                'lable1':ligne[1],
                                'lable2':ligne[2],
                                'lable3':ligne[3],
                                'lable4':ligne[4],
                                'lable5':ligne[5],
                                'start_time':ligne[6][0:4]+'-'+ligne[6][4:6]+'-'+ligne[6][6:8]+' '+ligne[6][8:10]+':'+ligne[6][10:12]+':'+ligne[6][12:14],
                                'end_time':ligne[7][0:4]+'-'+ligne[7][4:6]+'-'+ligne[7][6:8]+' '+ligne[7][8:10]+':'+ligne[7][10:12]+':'+ligne[7][12:14],
                                'call_read':ligne[8],
                                'billed_duration':ligne[9],
                                'lable10':ligne[10],
                                'lable11':ligne[11],
                                'lable12':ligne[12],
                                'lable13':ligne[13],
                                'traffic_type':ligne[14],
                                'traffic_sous_type':ligne[15],
                                'lable16':ligne[16],
                                'lable17':ligne[17],
                                'montant_facturé':ligne[18],
                                'cout_utilisation':ligne[19],
                                'cout_revendeur':ligne[20],
                                'lable21':ligne[21],
                                'lable22':ligne[22],
                                'lable23':ligne[23],
                                'lable24':ligne[24],
                                'lable25':ligne[25],
                                'lable26':ligne[26],
                                'lable27':ligne[27],
                                'lable28':ligne[28],
                                'lable29':ligne[29],
                                'lable30':ligne[30],
                                'lable31':ligne[31],
                                'profile':ligne[32],
                                'charging_server_ip ':ligne[33],
                                'ip_trunk_used':ligne[34],
                                'lable35':ligne[35],
                                'lable36':ligne[36],
                                'lable37':ligne[37],
                                'lable38':ligne[38],
                                'lable39':ligne[39],
                                'lable40':ligne[40],
                                'lable41':ligne[41],
                                'lable42':ligne[42],
                                'lable43':ligne[43],
                                'lable44':ligne[44],
                                'lable45':ligne[45],
                                'lable46':ligne[46],
                                'lable47':ligne[47],
                                'lable48':ligne[48],
                                'lable49':ligne[49],
                                'lable50':ligne[50],
                                'list_balance':list_balance,
                                'lable69':ligne[nb+1],
                                'lable70':ligne[nb+2],
                                'lable71': ligne[nb+3],
                                'lable72': ligne[nb+4],
                                'lable72': ligne[nb+5],
                                'lable73': ligne[nb+6],
                                'lable74': ligne[nb+7],
                                'lable75': ligne[nb+8],
                                'lable76': ligne[nb+9],
                                'lable77': ligne[nb+10],        
                                'lable78':ligne[nb+11],        
                                'lable79':ligne[nb+12],        
                                'lable80':ligne[nb+13],        
                                'lable81':ligne[nb+14],        
                                'lable82':ligne[nb+15],        
                                'lable83':ligne[nb+16],        
                                'lable84':ligne[nb+17],       
                                'lable85':ligne[nb+18],
                                'lable86':ligne[nb+19],
                                'lable87':ligne[nb+20],
                                'lable88':ligne[nb+21],
                                'lable89':ligne[nb+22],
                                'lable90':ligne[nb+23],
                                'lable91':ligne[nb+24],
                                'lable92':ligne[nb+25],
                                'lable93':ligne[nb+26],
                                'lable94':ligne[nb+27],
                            }
                        #print(dis_labl)
        
                else:

                    try: 

                        li_new1 = []

                        for z in range(int(ligne[51])):
                            tab=z*6
                            nb2=51+tab+1
                            li_new1.append(ligne[nb2])
                            nb2=51+tab+2
                            li_new1.append(ligne[nb2])
                            nb2=51+tab+3
                            li_new1.append(ligne[nb2])
                            nb2=51+tab+4
                            li_new1.append(ligne[nb2])
                            nb2=51+tab+5
                            li_new1.append(ligne[nb2])
                            nb2=51+tab+6
                            li_new1.append(ligne[nb2])    

                ###############################################################
                        list_balance1 = []
                        
                        for z in range(int(len(li_new1)/6)):
                            k=z*6
                            dis_balance1={
                                            "balance_name":li_new[k+0],
                                            "billed_amount":li_new[k+1],
                                            "balances_unit":li_new[k+2],
                                            "balan_credit_before":li_new[k+3],
                                            "after_call":li_new[k+4],
                                            "balance_expiration_date":li_new[k+5],
                                }
                    
                            list_balance1.append(dis_balance1)

                        dis_labl= {
                                'id':ligne[0],
                                'lable1':ligne[1],
                                'lable2':ligne[2],
                                'lable3':ligne[3],
                                'lable4':ligne[4],
                                'lable5':ligne[5],
                                'start_time':ligne[6][0:4]+'-'+ligne[6][4:6]+'-'+ligne[6][6:8]+' '+ligne[6][8:10]+':'+ligne[6][10:12]+':'+ligne[6][12:14],
                                'end_time':ligne[7][0:4]+'-'+ligne[7][4:6]+'-'+ligne[7][6:8]+' '+ligne[7][8:10]+':'+ligne[7][10:12]+':'+ligne[7][12:14],
                                'call_read':ligne[8],
                                'billed_duration':ligne[9],
                                'lable10':ligne[10],
                                'lable11':ligne[11],
                                'lable12':ligne[12],
                                'lable13':ligne[13],
                                'traffic_type':ligne[14],
                                'traffic_sous_type':ligne[15],
                                'lable16':ligne[16],
                                'lable17':ligne[17],
                                'montant_facturé':ligne[18],
                                'cout_utilisation':ligne[19],
                                'cout_revendeur':ligne[20],
                                'lable21':ligne[21],
                                'lable22':ligne[22],
                                'lable23':ligne[23],
                                'lable24':ligne[24],
                                'lable25':ligne[25],
                                'lable26':ligne[26],
                                'lable27':ligne[27],
                                'lable28':ligne[28],
                                'lable29':ligne[29],
                                'lable30':ligne[30],
                                'lable31':ligne[31],
                                'profile':ligne[32],
                                'charging_server_ip ':ligne[33],
                                'ip_trunk_used':ligne[34],
                                'lable35':ligne[35],
                                'lable36':ligne[36],
                                'lable37':ligne[37],
                                'lable38':ligne[38],
                                'lable39':ligne[39],
                                'lable40':ligne[40],
                                'lable41':ligne[41],
                                'lable42':ligne[42],
                                'lable43':ligne[43],
                                'lable44':ligne[44],
                                'lable45':ligne[45],
                                'lable46':ligne[46],
                                'lable47':ligne[47],
                                'lable48':ligne[48],
                                'lable49':ligne[49],
                                'lable50':ligne[50],
                                'list_balance':list_balance,
                                'lable69' :ligne[nb+1],
                                'lable70':ligne[nb+2],
                                'lable71': ligne[nb+3],
                                'lable72': ligne[nb+4],
                                'lable72': ligne[nb+5],
                                'lable73': ligne[nb+6],
                                'lable74': ligne[nb+7],
                                'lable75': ligne[nb+8],
                                'lable76': ligne[nb+9],
                                'lable77': ligne[nb+10],        
                                'lable78':ligne[nb+11],        
                                'lable79':ligne[nb+12],        
                                'lable80':ligne[nb+13],        
                                'lable81':ligne[nb+14],        
                                'lable82':ligne[nb+15],        
                                'lable83':ligne[nb+16],        
                                'lable84':ligne[nb+17],       
                                'lable85':'',
                                'lable86':'',
                                'lable87':'',
                                'lable88':'',
                                'lable89':'',
                                'lable90':'',
                                'lable91':'',
                                'lable92':'',
                                'lable93':'',
                                'lable94':'',   
                                }
                        #print(dis_labl)
                        

                    except IndexError:
                        print('')
                
        list_dict.append(dis_labl)
    print(list_dict[1])
# Out:
# {'id': 'PPDV$0169', 'lable1': 'X', 'lable2': '021B', 'lable3': '62dd404f-4cdb-ec13-4548fa96', 'lable4': 'V', 'lable5': 'O', 'start_time': '2022-07-24 15:51:27', 'end_time': '2022-07-24 15:51:27', 'call_read': '0', 'billed_duration': '0', 'lable10': 'X', 'lable11': '25321346383', 'lable12': '25321346383', 'lable13': '25377734016', 'traffic_type': 'VOICE', 'traffic_sous_type': 'VOICE', 'lable16': '1000', 'lable17': 'X', 'montant_facturé': '0', 'cout_utilisation': '0', 'cout_revendeur': '0', 'lable21': 'MYRATEPLAN', 'lable22': '1', 'lable23': 'X', 'lable24': 'X', 'lable25': '1', 'lable26': '15561', 'lable27': '15561', 'lable28': 'X', 'lable29': '1', 'lable30': '1', 'lable31': '1', 'profile': 'PREP5_EMP_C', 'charging_server_ip ': '10.155.42.1', 'ip_trunk_used': '10.224.248.132', 'lable35': '480', 'lable36': '20500725000000', 'lable37': 'X', 'lable38': 'DJIBOUTI_MOBILE', 'lable39': 'DJIBOUTI_FIXE', 'lable40': 'X', 'lable41': 'X', 'lable42': 'X', 'lable43': 'X', 'lable44': 'X', 'lable45': 
# ...

# %%
import psycopg2
from psycopg2 import Error
try:
    # Connect to an existing database
    connection = psycopg2.connect( user = "med_kadir",
                                   password = "medkadir",
                                   host = "localhost",
                                   port = "5432",
                                   database = "bdmed_kadir")

    cursor = connection.cursor()
    # SQL query to create a new table 
    ### insertion de données 
    for x in range(len(list_dict)):
        print(len(list_dict))
        print(list_dict[x])
        new_list_balance = ''.join(map(str, list_dict[x]['list_balance']))
        nlb = ''
        for e in range(len(new_list_balance)):
            if new_list_balance[e]=="'":
                nlb=nlb+'"'
            else:
                nlb=nlb+new_list_balance[e]
       
        insert_query ="INSERT INTO mkm_ocs_voix (id, lable1, lable2, lable3, lable4, lable5, start_time, end_time, call_read, billed_duration, lable10, lable11, lable12, lable13, traffic_type, traffic_sous_type, lable16, lable17, montant_facturé, cout_utilisation, cout_revendeur, lable21, lable22, lable23, lable24, lable25, lable26, lable27, lable28, lable29, lable30, lable31, profile, charging_server_ip ,ip_trunk_used, lable35, lable36, lable37, lable38, lable39, lable40, lable41, lable42, lable43, lable44, lable45, lable46, lable47, lable48, lable49, lable50, list_balance,lable69,lable70,lable71,lable72,lable73,lable74,lable75,lable76,lable77,lable78,lable79,lable80,lable81,lable82,lable83,lable84,lable85,lable86,lable87,lable88,lable89,lable90,lable91,lable92,lable93,lable94) VALUES ('"+list_dict[x]['id']+"', '"+list_dict[x]['lable1']+"', '"+list_dict[x]['lable2']+"', '"+list_dict[x]['lable3']+"', '"+list_dict[x]['lable4']+"', '"+list_dict[x]['lable5']+"', '"+list_dict[x]['start_time']+"', '"+list_dict[x]['end_time']+"', '"+list_dict[x]['call_read']+"', '"+list_dict[x]['billed_duration']+"', '"+list_dict[x]['lable10']+"', '"+list_dict[x]['lable11']+"', '"+list_dict[x]['lable12']+"', '"+list_dict[x]['lable13']+"', '"+list_dict[x]['traffic_type']+"', '"+list_dict[x]['traffic_sous_type']+"', '"+list_dict[x]['lable16']+"', '"+list_dict[x]['lable17']+"', '"+list_dict[x]['montant_facturé']+"', '"+list_dict[x]['cout_utilisation']+"', '"+list_dict[x]['cout_revendeur']+"', '"+list_dict[x]['lable21']+"', '"+list_dict[x]['lable22']+"', '"+list_dict[x]['lable23']+"', '"+list_dict[x]['lable24']+"', '"+list_dict[x]['lable25']+"', '"+list_dict[x]['lable26']+"', '"+list_dict[x]['lable27']+"', '"+list_dict[x]['lable28']+"', '"+list_dict[x]['lable29']+"', '"+list_dict[x]['lable30']+"', '"+list_dict[x]['lable31']+"', '"+list_dict[x]['profile']+"','"+list_dict[x]['charging_server_ip ']+"', '"+list_dict[x]['ip_trunk_used']+"', '"+list_dict[x]['lable35']+"', '"+list_dict[x]['lable36']+"', '"+list_dict[x]['lable37']+"', '"+list_dict[x]['lable38']+"', '"+list_dict[x]['lable39']+"', '"+list_dict[x]['lable40']+"', '"+list_dict[x]['lable41']+"', '"+list_dict[x]['lable42']+"', '"+list_dict[x]['lable43']+"', '"+list_dict[x]['lable44']+"', '"+list_dict[x]['lable45']+"', '"+list_dict[x]['lable46']+"', '"+list_dict[x]['lable47']+"', '"+list_dict[x]['lable48']+"', '"+list_dict[x]['lable49']+"', '"+list_dict[x]['lable50']+"', '"+nlb+"', '"+list_dict[x]['lable69']+"', '"+list_dict[x]['lable70']+"', '"+list_dict[x]['lable71']+"', '"+list_dict[x]['lable72']+"', '"+list_dict[x]['lable73']+"', '"+list_dict[x]['lable74']+"', '"+list_dict[x]['lable75']+"', '"+list_dict[x]['lable76']+"', '"+list_dict[x]['lable77']+"', '"+list_dict[x]['lable78']+"', '"+list_dict[x]['lable79']+"', '"+list_dict[x]['lable80']+"', '"+list_dict[x]['lable81']+"', '"+list_dict[x]['lable82']+"', '"+list_dict[x]['lable83']+"', '"+list_dict[x]['lable84']+"', '"+list_dict[x]['lable85']+"', '"+list_dict[x]['lable86']+"', '"+list_dict[x]['lable87']+"', '"+list_dict[x]['lable88']+"', '"+list_dict[x]['lable89']+"','"+list_dict[x]['lable90']+"', '"+list_dict[x]['lable91']+"', '"+list_dict[x]['lable92']+"', '"+list_dict[x]['lable93']+"', '"+list_dict[x]['lable94']+"');"
    
        cursor.execute(insert_query)
        connection.commit()
        print("Table à ete bien intesr")

    cursor.close()
    connection.close()
    print("PostgreSQL connection is closed")
except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
# Out:
# 1733
# ...
