# %%
import gzip
import os

path ='./cdr_file/'
var = os.listdir(path)

list_dict = []

for x in var:
    path ='./cdr_file/'+x
    with gzip.open(path, 'rb') as f:
        file_content = f.read()
    
    all_cdr_in_file = file_content.decode('UTF-8')

    list_of_cdr = list(all_cdr_in_file.split("\n"))

    for y in list_of_cdr:

        ligne = list(y.split(" "))
        
        if 'XML' in ligne:
#######################################-------------dictionair-----###############################################################
            li_new=[]
            for z in range(int(ligne[51])):
                tab=z*6
                nb=51+tab+1
                li_new.append(ligne[nb])
                nb=51+tab+2
                li_new.append(ligne[nb])
                nb=51+tab+3
                li_new.append(ligne[nb])
                nb=51+tab+4
                li_new.append(ligne[nb])
                nb=51+tab+5
                li_new.append(ligne[nb])
                nb=51+tab+6
                li_new.append(ligne[nb])    

            
        ###############################################################
            list_balance = []
            
            
            for z in range(int(len(li_new)/6)):
                k=z*6
                dis_balance={
                    "balance_name":li_new[k+0],
                    "lable":li_new[k+1],
                    "type":li_new[k+2],
                    "lable0":li_new[k+3],
                    "lable1":li_new[k+4],
                    "data_entry":li_new[k+5]
                }
        
                list_balance.append(dis_balance)
            
            #print(list_balance)
            
            #print(ligne)
            list_news=[]

            sub = ligne[nb+1]
            lab = ligne[nb+2]
            lab1= ligne[nb+3]
            lab2= ligne[nb+4]
            lab3= ligne[nb+5]
            lab4= ligne[nb+6]
            lab5= ligne[nb+7]
            lab6= ligne[nb+8]
            lab7= ligne[nb+9]
                

            for d in range(int(ligne[nb+10])):
                t=d*9
                nb1=nb+10+t+1
                list_news.append(ligne[nb1])
                nb1=nb+10+t+2
                list_news.append(ligne[nb1])
                nb1=nb+10+t+3
                list_news.append(ligne[nb1])
                nb1=nb+10+t+4
                list_news.append(ligne[nb1])
                nb1=nb+10+t+5
                list_news.append(ligne[nb1])
                nb1=nb+10+t+6
                list_news.append(ligne[nb1])     
                nb1=nb+10+t+7
                list_news.append(ligne[nb1])     
                nb1=nb+10+t+8
                list_news.append(ligne[nb1])     
                nb1=nb+10+t+9
                list_news.append(ligne[nb1])     

            #print(list_update)
            list_update=[]
            
            for z in range(int(len(list_news)/9)):
                k=z*9
                dis_update={
                "update_name":list_news[k+0],
                "lable0":list_news[k+1],
                "lable1":list_news[k+2],
                "lable2":list_news[k+3],
                "lable3":list_news[k+4],
                "lable4":list_news[k+5],
                "lable5":list_news[k+6],
                "lable6":list_news[k+7],
                "lable7":list_news[k+8]
                }
                list_update.append(dis_update)
            #print(list_update)
    ##########################################################################################################################
            dis_labl= {
                'Ip':ligne[0],
                'lable1':ligne[1],
                'lable2':ligne[2],
                'lable3':ligne[3],
                'lable4':ligne[4],
                'lable5':ligne[5],
                'data_start':ligne[6][0:4]+'-'+ligne[6][4:6]+'-'+ligne[6][6:8]+' '+ligne[6][8:10]+':'+ligne[6][10:12]+':'+ligne[6][12:14],
                'lable7':ligne[7],
                'lable8':ligne[8],
                'lable9':ligne[9],
                'lable10':ligne[10],
                'data_end':ligne[11],
                'lable12':ligne[12],
                'lable13':ligne[13],
                'lable14':ligne[14],
                'lable15':ligne[15],
                'lable16':ligne[16],
                'lable17':ligne[17],
                'lable18':ligne[18],
                'lable19':ligne[19],
                'lable20':ligne[20],
                'lable21':ligne[21],
                'lable22':ligne[22],
                'lable23':ligne[23],
                'lable24':ligne[24],
                'lable25':ligne[25],
                'lable26':ligne[26],
                'lable27':ligne[27],
                'lable28':ligne[28],
                'lable29':ligne[29],
                'lable30':ligne[30],
                'lable31':ligne[31],
                'profile_etudiant':ligne[32],
                'adresse_ip':ligne[33],
                'lable34':ligne[34],
                'lable35':ligne[35],
                'lable36':ligne[36],
                'lable37':ligne[37],
                'lable38':ligne[38],
                'lable39':ligne[39],
                'lable40':ligne[40],
                'lable41':ligne[41],
                'lable42':ligne[42],
                'lable43':ligne[43],
                'lable44':ligne[44],
                'lable45':ligne[45],
                'lable46':ligne[46],
                'lable47':ligne[47],
                'lable48':ligne[48],
                'lable49':ligne[49],
                'lable50':ligne[50],
                'list_balance': list_balance,
                'SUBSCRIBER': sub,
                'sublable':lab,
                'sublable1':lab1,
                'sublable2':lab2,
                'sublable3':lab3,
                'sublable4':lab4,
                'sublable5':lab5,
                'sublable6':lab6,
                'sublable7':lab7,      
                'list_update': list_update,

                }
            #print(dis_labl)
        
        if 'DIAMETER' in ligne:

            li_new1 = []
            for z in range(int(ligne[51])):
                tab=z*6
                nb2=51+tab+1
                li_new1.append(ligne[nb2])
                nb2=51+tab+2
                li_new1.append(ligne[nb2])
                nb2=51+tab+3
                li_new1.append(ligne[nb2])
                nb2=51+tab+4
                li_new1.append(ligne[nb2])
                nb2=51+tab+5
                li_new1.append(ligne[nb2])
                nb2=51+tab+6
                li_new1.append(ligne[nb2])    

            
        ###############################################################
            list_balance1 = []
            
            for z in range(int(len(li_new1)/6)):
                k=z*6
                dis_balance1={
                    "balance_name":li_new1[k+0],
                    "lable":li_new1[k+1],
                    "type":li_new1[k+2],
                    "lable0":li_new1[k+3],
                    "lable1":li_new1[k+4],
                    "data_entry":li_new1[k+5]
                }
        
                list_balance1.append(dis_balance1)
            
            
            list_news1=[]

            sub = ligne[nb2+1]
            lab = ligne[nb2+2]
            lab1= ligne[nb2+3]
            lab2= ligne[nb2+4]
            lab3= ligne[nb2+5]
            lab4= ligne[nb2+6]
            lab5= ligne[nb2+7]
            lab6= ligne[nb2+8]
            lab7= ligne[nb2+9]
                

            for h in range(int(ligne[nb2+10])):
                t=h*9
                nb3=nb2+10+t+1
                list_news1.append(ligne[nb3])
                nb3=nb2+10+t+2
                list_news1.append(ligne[nb3])
                nb3=nb2+10+t+3
                list_news1.append(ligne[nb3])
                nb3=nb2+10+t+4
                list_news1.append(ligne[nb3])
                nb3=nb2+10+t+5
                list_news1.append(ligne[nb3])
                nb3=nb2+10+t+6
                list_news.append(ligne[nb3])     
                nb3=nb2+10+t+7
                list_news1.append(ligne[nb3])     
                nb3=nb2+10+t+8
                list_news1.append(ligne[nb3])     
                nb3=nb2+10+t+9
                list_news1.append(ligne[nb3])     

            list_update_1=[]
            
            for p in range(int(len(list_news1)/8)):
                k=p*8
                dis_update_1={
                    "update_name":list_news1[k+0],
                    "lable0":list_news1[k+1],
                    "lable1":list_news1[k+2],
                    "lable2":list_news1[k+3],
                    "lable3":list_news1[k+4],
                    "lable4":list_news1[k+5],
                    "lable5":list_news1[k+6],
                    "lable6":list_news1[k+7],
                            
                }
                list_update_1.append(dis_update_1)
 
            dis_labl= {
                'Ip':ligne[0],
                'lable1':ligne[1],
                'lable2':ligne[2],
                'lable3':ligne[3],
                'lable4':ligne[4],
                'lable5':ligne[5],
                'data_start':ligne[6][0:4]+'-'+ligne[6][4:6]+'-'+ligne[6][6:8]+' '+ligne[6][8:10]+':'+ligne[6][10:12]+':'+ligne[6][12:14],
                'lable7':ligne[7],
                'lable8':ligne[8],
                'lable9':ligne[9],
                'lable10':ligne[10],
                'data_end':ligne[11],
                'lable12':ligne[12],
                'lable13':ligne[13],
                'lable14':ligne[14],
                'lable15':ligne[15],
                'lable16':ligne[16],
                'lable17':ligne[17],
                'lable18':ligne[18],
                'lable19':ligne[19],
                'lable20':ligne[20],
                'lable21':ligne[21],
                'lable22':ligne[22],
                'lable23':ligne[23],
                'lable24':ligne[24],
                'lable25':ligne[25],
                'lable26':ligne[26],
                'lable27':ligne[27],
                'lable28':ligne[28],
                'lable29':ligne[29],
                'lable30':ligne[30],
                'lable31':ligne[31],
                'profile_etudiant':ligne[32],
                'adresse_ip':ligne[33],
                'lable34':ligne[34],
                'lable35':ligne[35],
                'lable36':ligne[36],
                'lable37':ligne[37],
                'lable38':ligne[38],
                'lable39':ligne[39],
                'lable40':ligne[40],
                'lable41':ligne[41],
                'lable42':ligne[42],
                'lable43':ligne[43],
                'lable44':ligne[44],
                'lable45':ligne[45],
                'lable46':ligne[46],
                'lable47':ligne[47],
                'lable48':ligne[48],
                'lable49':ligne[49],
                'lable50':ligne[50],
                'list_balance':list_balance1,
                'SUBSCRIBER':sub,
                'sublable':lab,
                'sublable1':lab1,
                'sublable2':lab2,
                'sublable3':lab3,
                'sublable4':lab4,
                'sublable5':lab5,
                'sublable6':lab6,
                'sublable7':lab7,      
                'list_update':list_update_1,
            }
    list_dict.append(dis_labl)
    #vqrq = ''.join(map(str, list_dict))
    #print(vqrq)

# %%
import psycopg2
from psycopg2 import Error

try:
    connection = psycopg2.connect( user = "med_kadir",
                                   password = "medkadir",
                                   host = "localhost",
                                   port = "5432",
                                   database = "bdmed_kadir")


    cursor = connection.cursor()
    # SQL query to create a new table
    create_table_query = '''CREATE TABLE Projet_stage_
          ( ID int NOT NULL,
          ip               TEXT      NOT NULL,
          lable1           TEXT    NOT NULL,
          lable2           TEXT    NOT NULL,
          lable3           TEXT    NOT NULL,
          lable4           TEXT    NOT NULL,
          lable5       TEXT    NOT NULL,
          data_start           TEXT    NOT NULL,
          lable7           TEXT    NOT NULL,
          lable8           TEXT    NOT NULL,
          lable9           TEXT    NOT NULL,
          lable10           TEXT    NOT NULL,
          data_end           TEXT    NOT NULL,
          lable12          TEXT    NOT NULL,
          lable13           TEXT    NOT NULL,
          lable14          TEXT    NOT NULL,
          lable15           TEXT    NOT NULL,
          lable16           TEXT    NOT NULL,
          lable17           TEXT    NOT NULL,
          lable18           TEXT    NOT NULL,
          lable19           TEXT    NOT NULL,
          lable20          TEXT    NOT NULL,
          lable21          TEXT    NOT NULL,
          lable22           TEXT    NOT NULL,
          lable23           TEXT    NOT NULL,
          lable24           TEXT    NOT NULL,
          lable25           TEXT    NOT NULL,
          lable26           TEXT    NOT NULL,
          lable27           TEXT    NOT NULL,
          lable28           TEXT    NOT NULL,
          lable29           TEXT    NOT NULL,
          lable30           TEXT    NOT NULL,
          lable31           TEXT    NOT NULL,
          profile_etudiant TEXT    NOT NULL,
          adresse_ip           TEXT    NOT NULL,
          lable34           TEXT    NOT NULL,
          lable35           TEXT    NOT NULL,
          lable36           TEXT    NOT NULL,
          lable37           TEXT    NOT NULL,
          lable38           TEXT    NOT NULL,
          lable39           TEXT    NOT NULL,
          lable40           TEXT    NOT NULL,
          lable41           TEXT    NOT NULL,
          lable42           TEXT    NOT NULL,
          lable43          TEXT    NOT NULL,
          lable44           TEXT    NOT NULL,
          lable45           TEXT    NOT NULL,
          lablE46           TEXT    NOT NULL,
          lable47           TEXT    NOT NULL,
          lable48           TEXT    NOT NULL,
          lable49           TEXT    NOT NULL,
          lable50           TEXT    NOT NULL,
          list_balance      TEXT    NOT NULL,
          SUBSCRIBER        TEXT    NOT NULL,
          sublable         TEXT    NOT NULL,
          sublable1           TEXT    NOT NULL,
          sublable2           TEXT    NOT NULL,
          sublable3           TEXT    NOT NULL,
          sublable4           TEXT    NOT NULL,
          sublable5          TEXT    NOT NULL,
          sublable6          TEXT    NOT NULL,
          sublable7           TEXT    NOT NULL,
          list_update          TEXT    NOT NULL,
          PRIMARY KEY (ID)); '''
    # Execute a command: this creates a new table
    cursor.execute(create_table_query)
    connection.commit()
    print("Table created successfully in PostgreSQL ")

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Table created successfully in PostgreSQL
# PostgreSQL connection is closed

# %%
import psycopg2
from psycopg2 import Error
try:
    # Connect to an existing database
    connection = psycopg2.connect( user = "Premier_db",
                                   password = "med_kadir",
                                   host = "localhost",
                                   port = "5432",
                                   database = "Premier_1_db")

    cursor = connection.cursor()
    # SQL query to create a new table 
    ### insertion de données 
    for x in range(len(list_dict)):
        print(len(list_dict))
        print(list_dict[x])
        new_list_balance = ''.join(map(str, list_dict[x]['list_balance']))
        nlb = ''
        for e in range(len(new_list_balance)):
            if new_list_balance[e]=="'":
                nlb=nlb+'"'
            else:
                nlb=nlb+new_list_balance[e]
        new_list_update = ''.join(map(str, list_dict[x]['list_update']))
        nlu = ''
        for e in range(len(new_list_update)):
            if new_list_update[e]=="'":
                nlu=nlu+'"'
            else:
                nlu=nlu+new_list_update[e]
        insert_query ="INSERT INTO testdb_projetstage (ip, lable1, lable2, lable3, lable4, lable5, data_start, lable7, lable8, lable9, lable10, lable11, lable12, lable13, lable14, lable15, lable16, lable17, lable18, lable19, lable20, lable21, lable22, lable23, lable24, lable25, lable26, lable27, lable28, lable29, lable30, lable31, profile_etudiant, adresse_ip,lable34, lable35, lable36, lable37, lable38, lable39, lable40, lable41, lable42, lable43, lable44, lable45, lable46, lable47, lable48, lable49, lable50, list_balance,subscriber, sublable, sublable1, sublable2, sublable3, sublable4, sublable5, sublable6, sublable7, list_update) VALUES ('"+list_dict[x]['Ip']+"', '"+list_dict[x]['lable1']+"', '"+list_dict[x]['lable2']+"', '"+list_dict[x]['lable3']+"', '"+list_dict[x]['lable4']+"', '"+list_dict[x]['lable5']+"', '"+list_dict[x]['data_start']+"', '"+list_dict[x]['lable7']+"', '"+list_dict[x]['lable8']+"', '"+list_dict[x]['lable9']+"', '"+list_dict[x]['lable10']+"', '"+list_dict[x]['data_end']+"', '"+list_dict[x]['lable12']+"', '"+list_dict[x]['lable13']+"', '"+list_dict[x]['lable14']+"', '"+list_dict[x]['lable15']+"', '"+list_dict[x]['lable16']+"', '"+list_dict[x]['lable17']+"', '"+list_dict[x]['lable18']+"', '"+list_dict[x]['lable19']+"', '"+list_dict[x]['lable20']+"', '"+list_dict[x]['lable21']+"', '"+list_dict[x]['lable22']+"', '"+list_dict[x]['lable23']+"', '"+list_dict[x]['lable24']+"', '"+list_dict[x]['lable25']+"', '"+list_dict[x]['lable26']+"', '"+list_dict[x]['lable27']+"', '"+list_dict[x]['lable28']+"', '"+list_dict[x]['lable29']+"', '"+list_dict[x]['lable30']+"', '"+list_dict[x]['lable31']+"', '"+list_dict[x]['profile_etudiant']+"','"+list_dict[x]['adresse_ip']+"', '"+list_dict[x]['lable34']+"', '"+list_dict[x]['lable35']+"', '"+list_dict[x]['lable36']+"', '"+list_dict[x]['lable37']+"', '"+list_dict[x]['lable38']+"', '"+list_dict[x]['lable39']+"', '"+list_dict[x]['lable40']+"', '"+list_dict[x]['lable41']+"', '"+list_dict[x]['lable42']+"', '"+list_dict[x]['lable43']+"', '"+list_dict[x]['lable44']+"', '"+list_dict[x]['lable45']+"', '"+list_dict[x]['lable46']+"', '"+list_dict[x]['lable47']+"', '"+list_dict[x]['lable48']+"', '"+list_dict[x]['lable49']+"', '"+list_dict[x]['lable50']+"', '"+nlb+"', '"+list_dict[x]['SUBSCRIBER']+"', '"+list_dict[x]['sublable']+"', '"+list_dict[x]['sublable1']+"', '"+list_dict[x]['sublable2']+"', '"+list_dict[x]['sublable3']+"', '"+list_dict[x]['sublable4']+"', '"+list_dict[x]['sublable5']+"', '"+list_dict[x]['sublable6']+"', '"+list_dict[x]['sublable7']+"', '"+nlu+"');"
       
        cursor.execute(insert_query)
        connection.commit()
        print("Table à ete bien intesr")

    cursor.close()
    connection.close()
    print("PostgreSQL connection is closed")
except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
# Out:
# 1242
# ...
